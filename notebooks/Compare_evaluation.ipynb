# %%
import pandas as pd
import numpy as np

# %%
EVAL_FOLDER = '../evaluations'

# %%
def load_data(prefix, traffic):
    print("Loading", f'{EVAL_FOLDER}/{prefix}_{traffic}_1_episode.csv')
    df_single_episode = pd.read_csv(f'{EVAL_FOLDER}/{prefix}_{traffic}_1_episode.csv')
    df_single_episode = df_single_episode.set_index('step')
    df_single_episode = df_single_episode.drop(columns=['cumulative_reward'])
 
    
    df_multiple_episodes = pd.read_csv(f'{EVAL_FOLDER}/{prefix}_{traffic}_100_episode.csv')
    df_multiple_episodes = df_multiple_episodes.set_index('episode')
    # df_multiple_episodes = df_multiple_episodes.drop(columns=['cumulative_reward'])
    # df_multiple_episodes = None
    return df_single_episode, df_multiple_episodes

def compare_datasets(datasets):
    results = []
    for name, df in datasets:
        data = {
            'dataset': name,
#             'avg_cumulative_reward': np.mean(df.cumulative_reward.to_list()),
            # 'mean_waiting_time': np.mean(df.mean_waiting_time.to_list()),
            
            'avg_travel_time': np.mean(df.avg_travel_time.to_list()),
            'avg_time_loss': np.mean(df.avg_time_loss.to_list()),
            'avg_waiting_time': np.mean(df.avg_waiting_time.to_list()),

            'collisions': np.mean(df.collisions.to_list()),
            'emergency_braking': np.mean(df.emergency_braking.to_list()),
            'emergency_stops': np.mean(df.emergency_stops.to_list()),

#             'mean_speed': np.mean(df.mean_speed.to_list()),
            'mean_lane_density': np.mean(df.mean_lane_density.to_list()),
            'mean_queue': np.mean(df.mean_queue_length.to_list()),

        }
        results.append(data)
    return pd.DataFrame(results)

# %%
for traffic_scenario in ["cologne1", 
                         #"cologne3", "cologne8",
                         # "ingolstadt1", "ingolstadt7", # "ingolstadt21",
                         # "hangzhou_1x1_bc-tyc_18041607_1h", "jinan"
                        ]:
    models = ['cyclic_15',
              'max_pressure',
              'sotl',
              "option_critic_nn_2_options_cologne1_50400_steps"]
    datasets = [(model, load_data(f"{model}_{traffic_scenario}")[1])for model in models]
    df_comp = compare_datasets(datasets)
    print("Traffic scenario:", traffic_scenario)
    display(df_comp)
# Out:
# Traffic scenario: cologne1
#                                              model  avg_cumulative_reward  \
# 0                                        cyclic_15          -45878.460000
# 1                                     max_pressure           -8222.060000
# 2                                             sotl          -38059.530000
# 3  option_critic_nn_2_options_cologne1_50400_steps           -3949.901609
#
#    avg_travel_time  avg_time_loss  avg_waiting_time  collisions  \
# 0       159.180729       136.1910          118.4448        0.00
# 1        50.138978        27.3277           12.6825        0.04
# 2       124.885667       102.0007           76.1880        0.01
# 3       124.620850       101.7990           69.5920        0.04
#
#    emergency_braking  emergency_stops  mean_lane_density  mean_queue
# 0               0.00              0.0           4.146779   56.978375
# 1               0.41              0.0           1.233540    6.287736
# 2               0.05              0.0           3.135584   41.366014
# 3               0.45              0.0           3.082745   40.286611

# %%
for traffic_scenario in ["cologne3", ]:
    models = ['cyclic_15',
              'max_pressure',
              'sotl',
              "option_critic_nn_10_options_cologne3_50400_steps"]
    datasets = [(model, load_data(f"{model}_{traffic_scenario}")[1])for model in models]
    df_comp = compare_datasets(datasets)
    print("Traffic scenario:", traffic_scenario)
    display(df_comp)
# Out:
# Traffic scenario: cologne3
#                                               model  avg_cumulative_reward  \
# 0                                         cyclic_15          -12598.236667
# 1                                      max_pressure           -4489.573333
# 2                                              sotl           -9988.576667
# 3  option_critic_nn_10_options_cologne3_50400_steps           -3747.368043
#
#    avg_travel_time  avg_time_loss  avg_waiting_time  collisions  \
# 0       182.687647       145.1949          128.0003        0.00
# 1        70.219572        33.1275           19.4994        0.01
# 2       146.436842       108.9232           89.2438        0.00
# 3       112.002859        74.8356           54.1072        0.01
#
#    emergency_braking  emergency_stops  mean_lane_density  mean_queue
# 0               0.01              0.0           6.214961   53.210611
# 1               0.15              0.0           3.208170   22.273236
# 2               0.01              0.0           5.487933   41.177264
# 3               0.23              0.0           4.765415   32.880722

# %%
for traffic_scenario in ["cologne8", 
                        ]:
    models = ['cyclic_15',
              'max_pressure',
              'sotl',
              "option_critic_nn_10_options_cologne8_50400_steps"]
    datasets = [(model, load_data(f"{model}_{traffic_scenario}")[1])for model in models]
    df_comp = compare_datasets(datasets)
    print("Traffic scenario:", traffic_scenario)
    display(df_comp)
# Out:
# Traffic scenario: cologne8
#                                               model  avg_cumulative_reward  \
# 0                                         cyclic_15           -6138.533750
# 1                                      max_pressure           -2118.782500
# 2                                              sotl           -3902.527500
# 3  option_critic_nn_10_options_cologne8_50400_steps           -3620.770563
#
#    avg_travel_time  avg_time_loss  avg_waiting_time  collisions  \
# 0       237.008513       168.9497          141.5603         0.0
# 1       129.096103        63.0392           39.9736         0.0
# 2       177.424675       110.8019           83.5294         0.0
# 3       171.243417       103.8142           67.0022         0.0
#
#    emergency_braking  emergency_stops  mean_lane_density  mean_queue
# 0               0.03              0.0           4.455401   75.223833
# 1               0.20              0.0           2.064631   24.927972
# 2               0.00              0.0           3.155144   44.813861
# 3               0.18              0.0           2.727808   36.112361

# %%
traffic_scenario = 'cologne1'
prefix = ['fixed_period_15_steps', 'fixed_period_30_steps', 'dqn_cologne1', 'ppo_cologne1']
datasets = [(p, load_data(p, traffic_scenario)[1]) for p in prefix]
compare_datasets(datasets)
# Out:
# Loading ../evaluations/fixed_period_15_steps_cologne1_1_episode.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [9], in <cell line: 3>()
#       1 traffic_scenario = 'cologne1'
#       2 prefix = ['fixed_period_15_steps', 'fixed_period_30_steps', 'dqn_cologne1', 'ppo_cologne1']
# ----> 3 datasets = [(p, load_data(p, traffic_scenario)[1]) for p in prefix]
#       4 compare_datasets(datasets)
#
# Input In [9], in <listcomp>(.0)
#       1 traffic_scenario = 'cologne1'
#       2 prefix = ['fixed_period_15_steps', 'fixed_period_30_steps', 'dqn_cologne1', 'ppo_cologne1']
# ----> 3 datasets = [(p, load_data(p, traffic_scenario)[1]) for p in prefix]
#       4 compare_datasets(datasets)
#
# Input In [6], in load_data(prefix, traffic)
#       1 def load_data(prefix, traffic):
#       2     print("Loading", f'{EVAL_FOLDER}/{prefix}_{traffic}_1_episode.csv')
# ----> 3     df_single_episode = pd.read_csv(f'{EVAL_FOLDER}/{prefix}_{traffic}_1_episode.csv')
#       4     df_single_episode = df_single_episode.set_index('step')
#       5     df_single_episode = df_single_episode.drop(columns=['cumulative_reward'])
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../evaluations/fixed_period_15_steps_cologne1_1_episode.csv'

# %%
traffic_scenario = 'cologne1'
prefix = 'dqn_cologne1'
df_single_episode, df_multiple_episodes = load_data(prefix, traffic_scenario)
datasets = [(prefix, df_multiple_episodes)]
compare_datasets(datasets)
# Out:
#         dataset  avg_cumulative_reward  avg_travel_time  avg_time_loss  \
# 0  dqn_cologne1               -5558.13        42.699756        19.8797
#
#    avg_waiting_time  mean_lane_density  mean_queue
# 0            6.8324           0.925802    3.387014

# %%
MODELS = [
"a2c_partial_broken_3x3grid-3lanes2_250000_stepsintelli_light_prcol_reward_delay_3_waiting_time_2_light_switches_1_out_lanes_availability_1",
"option_critic_discrete_2_options_3x3grid-3lanes2_248400_steps",
"option_critic_discrete_curriculum_2_options_3x3grid-3lanes2_248400_steps",
# "option_critic_nn_2_options_3x3grid-3lanes2_248400_steps",
"option_critic_nn_curriculum_2_options_3x3grid-3lanes2_248400_steps",
]
                                        


traffic_scenario = "3x3grid-3lanes2"
prefix = [f"{model}_broken" for model in MODELS]
datasets = [(p, load_data(p, traffic_scenario)[1]) for p in prefix]
df_compare = compare_datasets(datasets)
# Out:
# Loading ../evaluations/a2c_partial_broken_3x3grid-3lanes2_250000_stepsintelli_light_prcol_reward_delay_3_waiting_time_2_light_switches_1_out_lanes_availability_1_broken_3x3grid-3lanes2_1_episode.csv
# Loading ../evaluations/option_critic_discrete_2_options_3x3grid-3lanes2_248400_steps_broken_3x3grid-3lanes2_1_episode.csv
# Loading ../evaluations/option_critic_discrete_curriculum_2_options_3x3grid-3lanes2_248400_steps_broken_3x3grid-3lanes2_1_episode.csv
# Loading ../evaluations/option_critic_nn_curriculum_2_options_3x3grid-3lanes2_248400_steps_broken_3x3grid-3lanes2_1_episode.csv

# %%
df_compare
# Out:
#                                              dataset  avg_travel_time  \
# 0  a2c_partial_broken_3x3grid-3lanes2_250000_step...       488.573038
# 1  option_critic_discrete_2_options_3x3grid-3lane...       545.924588
# 2  option_critic_discrete_curriculum_2_options_3x...       543.339244
# 3  option_critic_nn_curriculum_2_options_3x3grid-...       488.279850
#
#    avg_time_loss  avg_waiting_time  collisions  emergency_braking  \
# 0       428.0901          402.2789         0.0               0.01
# 1       485.4014          457.5553         0.0               0.01
# 2       482.8285          455.0099         0.0               0.02
# 3       440.2064          423.2901         0.0               0.00
#
#    emergency_stops  mean_lane_density  mean_queue
# 0             0.00           5.249558   83.186542
# 1             0.01           5.636513   89.645667
# 2             0.00           5.635004   89.649847
# 3             0.00          15.127674  265.813833

# %%
df_compare.to_csv("./df_compare.csv", index=False)
